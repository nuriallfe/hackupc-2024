# %%
import osmnx

PLACE_NAME = "Herat"


restaurants = osmnx.geometries_from_place(
    PLACE_NAME,
    {
        "amenity": "restaurant"
    }
)
len(restaurants) 
print(len(restaurants))
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_9432\1839398930.py:6: FutureWarning: The `geometries` module and `geometries_from_X` functions have been renamed the `features` module and `features_from_X` functions. Use these instead. The `geometries` module and function names are deprecated and will be removed in the v2.0.0 release. See the OSMnx v2 migration guide: https://github.com/gboeing/osmnx/issues/1123
#   restaurants = osmnx.geometries_from_place(
# c:\Users\Usuario\Documents\Projectes\Hack24\hackupc-2024\.venv\Lib\site-packages\osmnx\_overpass.py:254: UserWarning: This area is 28 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
# 4

# %%
graph = osmnx.graph_from_place(PLACE_NAME)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 graph = osmnx.graph_from_place(PLACE_NAME)
#
# File c:\Users\Usuario\Documents\Projectes\Hack24\hackupc-2024\.venv\Lib\site-packages\osmnx\graph.py:396, in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, which_result, buffer_dist, clean_periphery, custom_filter)
#     393 utils.log("Constructed place geometry polygon(s) to query API")
#     395 # create graph using this polygon(s) geometry
# --> 396 G = graph_from_polygon(
#     397     polygon,
#     398     network_type=network_type,
#     399     simplify=simplify,
#     400     retain_all=retain_all,
#     401     truncate_by_edge=truncate_by_edge,
#     402     clean_periphery=clean_periphery,
#     403     custom_filter=custom_filter,
#     404 )
#     406 utils.log(f"graph_from_place returned graph with {len(G):,} nodes and {len(G.edges):,} edges")
#     407 return G
#
# File c:\Users\Usuario\Documents\Projectes\Hack24\hackupc-2024\.venv\Lib\site-packages\osmnx\graph.py:508, in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, clean_periphery, custom_filter)
#     506 # simplify the graph topology
#     507 if simplify:
# --> 508     G_buff = simplification.simplify_graph(G_buff)
#     510 # truncate graph by original polygon to return graph within polygon
#     511 # caller wants. don't simplify again: this allows us to retain
#     512 # intersections along the street that may now only connect 2 street
#     513 # segments in the network, but in reality also connect to an
#     514 # intersection just outside the polygon
#     515 G = truncate.truncate_graph_polygon(G_buff, polygon, retain_all, truncate_by_edge)
#
# File c:\Users\Usuario\Documents\Projectes\Hack24\hackupc-2024\.venv\Lib\site-packages\osmnx\simplification.py:317, in simplify_graph(G, strict, edge_attrs_differ, endpoint_attrs, remove_rings, track_merged)
#     314 attrs_to_sum = {"length", "travel_time"}
#     316 # make a copy to not mutate original graph object caller passed in
# --> 317 G = G.copy()
#     318 initial_node_count = len(G)
#     319 initial_edge_count = len(G.edges)
#
# File c:\Users\Usuario\Documents\Projectes\Hack24\hackupc-2024\.venv\Lib\site-packages\networkx\classes\multigraph.py:1103, in MultiGraph.copy(self, as_view)
#    1101 G = self.__class__()
#    1102 G.graph.update(self.graph)
# -> 1103 G.add_nodes_from((n, d.copy()) for n, d in self._node.items())
#    1104 G.add_edges_from(
#    1105     (u, v, key, datadict.copy())
#    1106     for u, nbrs in self._adj.items()
#    1107     for v, keydict in nbrs.items()
#    1108     for key, datadict in keydict.items()
#    1109 )
#    1110 return G
#
# File c:\Users\Usuario\Documents\Projectes\Hack24\hackupc-2024\.venv\Lib\site-packages\networkx\classes\digraph.py:547, in DiGraph.add_nodes_from(self, nodes_for_adding, **attr)
#     545         self._pred[n] = self.adjlist_inner_dict_factory()
#     546         self._node[n] = self.node_attr_dict_factory()
# --> 547     self._node[n].update(newdict)
#     548 nx._clear_cache(self)
#
# KeyboardInterrupt:

# %%
nodes, edges = osmnx.graph_to_gdfs(graph)

# %%
import matplotlib
figure, ax = matplotlib.pyplot.subplots(figsize=(12,8))

# Plot the footprint
area.plot(ax=ax, facecolor="black")
# Plot restaurants
restaurants.plot(ax=ax, color="yellow", alpha=0.4, markersize=10)
# Out:
# <Axes: >

# %%
area = osmnx.geocode_to_gdf(PLACE_NAME)

# %%
area.plot()
# Out:
# c:\Users\Usuario\Documents\Projectes\Hack24\hackupc-2024\.venv\Lib\site-packages\IPython\core\pylabtools.py:77: DeprecationWarning: backend2gui is deprecated since IPython 8.24, backends are managed in matplotlib and can be externally registered.
#   warnings.warn(
# <Axes: >

# %%
restaurants.columns
# Out:
# Index(['addr:housenumber', 'addr:postcode', 'addr:street', 'amenity',
#        'indoor_seating', 'name', 'outdoor_seating', 'geometry', 'name:ca',
#        'phone',
#        ...
#        'contact:postcode', 'contact:street', 'name:etymology:wikidata',
#        'historic', 'amenity_1', 'building:part', 'building:material', 'height',
#        'ways', 'type'],
#       dtype='object', length=220)

# %%
restaurants["diet:vegan"].dropna()
# Out:
# element_type  osmid
# node          573484598      yes
#               588003295       no
#               949553814      yes
#               1271879449     yes
#               1340330370     yes
#                             ...
#               11737536998    yes
#               11752680928    yes
#               11775672687    yes
#               11819919935    yes
# way           326759094      yes
# Name: diet:vegan, Length: 107, dtype: object
