# %%
emblematic_european_sites = [
    "Torre Eiffel, París, Francia",
    "Coliseo, Roma, Italia",
    "Sagrada Familia, Barcelona, España",
    "Big Ben y las Casas del Parlamento, Londres, Reino Unido",
    "Acrópolis de Atenas, Grecia",
    "Catedral de San Basilio, Moscú, Rusia",
    "Torre de Pisa, Italia",
    "Catedral de Notre Dame, París, Francia",
    "Alhambra, Granada, España",
    "Puente de la Torre, Londres, Reino Unido",
    "Palacio de Schönbrunn, Viena, Austria",
    "Museo del Louvre, París, Francia",
    "Puerta de Brandeburgo, Berlín, Alemania",
    "Palacio de Buckingham, Londres, Reino Unido",
    "Castillo de Neuschwanstein, Baviera, Alemania",
    "Manneken Pis, Bruselas, Bélgica",
    "Palacio de Versalles, Versalles, Francia",
    "Stonehenge, Amesbury, Reino Unido",
    "Basílica de San Pedro, Ciudad del Vaticano",
    "Murallas de Dubrovnik, Croacia",
    "Palacio de Westminster, Londres, Reino Unido",
    "Plaza Roja, Moscú, Rusia",
    "Monte Saint-Michel, Normandía, Francia",
    "Partenón, Atenas, Grecia",
    "Catedral de Milán, Milán, Italia",
    "Plaza de España, Sevilla, España",
    "La Grand-Place, Bruselas, Bélgica",
    "Torre de Belém, Lisboa, Portugal",
    "Catedral de San Pablo, Londres, Reino Unido",
    "Kremlin, Moscú, Rusia",
    "Palacio de Diocleciano, Split, Croacia",
    "Castillo de Edimburgo, Edimburgo, Escocia",
    "Castillo de Praga, Praga, República Checa",
    "Panteón, Roma, Italia",
    "Catedral de Florencia, Florencia, Italia",
    "Atomium, Bruselas, Bélgica",
    "Palacio Real, Madrid, España",
    "La Fontana di Trevi, Roma, Italia",
    "Catedral de San Isaac, San Petersburgo, Rusia",
    "Galería Uffizi, Florencia, Italia",
    "Palacio de Charlottenburg, Berlín, Alemania",
    "Torre de Londres, Londres, Reino Unido",
    "Puente Carlos, Praga, República Checa",
    "Museo del Hermitage, San Petersburgo, Rusia",
    "La Scala, Milán, Italia",
    "Basílica de San Marcos, Venecia, Italia",
    "Catedral de Santiago de Compostela, España",
    "Arena de Verona, Verona, Italia",
    "Catedral de Chartres, Chartres, Francia",
    "Catacumbas de París, Francia",
    "Teatro de Epidauro, Grecia",
    "Casa de Ana Frank, Ámsterdam, Países Bajos",
    "Museo Van Gogh, Ámsterdam, Países Bajos",
    "Plaza de San Pedro, Ciudad del Vaticano",
    "Palacio Real de Caserta, Caserta, Italia",
    "Sistema de Museos Vaticanos, Ciudad del Vaticano",
    "Capilla Sixtina, Ciudad del Vaticano",
    "Monasterio de El Escorial, Madrid, España",
    "Torre de Hércules, La Coruña, España",
    "Catedral de Salamanca, Salamanca, España",
    "Monasterio de Montserrat, Barcelona, España",
    "Castillo de Windsor, Windsor, Reino Unido",
    "Parlamento Húngaro, Budapest, Hungría",
    "Real Alcázar de Sevilla, Sevilla, España",
    "Teatro Nacional de la Ópera y Ballet de Noruega, Oslo, Noruega",
    "Catedral de Ruan, Ruan, Francia",
    "Museo de Orsay, París, Francia",
    "Arco del Triunfo, París, Francia",
    "Catedral de Lincoln, Lincoln, Reino Unido",
    "Catedral de San Vito, Praga, República Checa",
    "Galería de los Uffizi, Florencia, Italia",
    "Mont Blanc, Alpes, Francia/Italia",
    "Fiordo de Geiranger, Noruega",
    "Lago Bled, Eslovenia",
    "Costa Amalfitana, Italia",
    "Calzada del Gigante, Irlanda del Norte, Reino Unido",
    "Parque Nacional de Plitvice, Croacia",
    "Isla de Santorini, Grecia",
    "Capadocia, Turquía",
    "Monte Etna, Sicilia, Italia",
    "Cliffs of Moher, Irlanda",
    "Monte Olympus, Grecia",
    "Laponia, Finlandia",
    "Los Alpes Suizos, Suiza",
    "Volcán Vesuvio, Italia",
    "Islas Lofoten, Noruega",
    "Parque Nacional de los Lagos de Killarney, Irlanda",
    "Lago Como, Italia",
    "Glaciar Vatnajökull, Islandia",
    "Valle de Loira, Francia",
    "Dolomitas, Italia",
    "Las Médulas, España",
    "Círculo de Piedras de Stonehenge, Reino Unido",
    "Cueva de Altamira, España",
    "Caminito del Rey, Málaga, España",
    "Puente del Gard, Francia",
    "Castillo de Chambord, Francia",
    "Catedral de Sevilla, Sevilla, España",
    "Museo Picasso, Málaga, España",
    "Bosque de Białowieża, Polonia/Bielorrusia",
    "Picos de Europa, España",
    "Lago Ness, Escocia",
    "Cueva de Postojna, Eslovenia",
    "La Riviera Francesa, Francia",
    "Cascadas de Kravica, Bosnia y Herzegovina",
    "Monte Cervino, Suiza/Italia",
    "Parque Nacional de Timanfaya, Lanzarote, España",
    "Las islas griegas, Grecia",
        "La Roca de Gibraltar, Gibraltar",
    "Catedral de San Esteban, Viena, Austria",
    "La Garganta del Verdon, Francia",
    "Museo Guggenheim, Bilbao, España",
    "Palacio de Peles, Sinaia, Rumania",
    "Catedral de York Minster, York, Reino Unido",
    "La Muralla de Ávila, España",
    "Palacio de Catherine, Pushkin, Rusia",
    "Catedral de San Esteban, Budapest, Hungría",
    "Monte Athos, Grecia",
    "Las Grutas de Postojna, Eslovenia",
    "Blenheim Palace, Oxfordshire, Reino Unido",
    "Forth Bridge, Escocia",
    "Palacio de la Magdalena, Santander, España",
    "Túnel del Canal de la Mancha, entre Reino Unido y Francia",
    "Convento de Cristo, Tomar, Portugal",
    "Las Islas Feroe, Dinamarca",
    "Catedral de Santa María del Fiore, Florencia, Italia",
    "Museo Nacional de Arte de Cataluña, Barcelona, España",
    "Museo de Historia Natural, Londres, Reino Unido",
    "La Ciudad de Luxemburgo, Luxemburgo",
    "Palacio del Príncipe, Mónaco",
    "Abadía de Melk, Austria",
    "Las Salinas de Wieliczka, Polonia",
    "Mont Sainte-Odile, Francia",
    "Casco antiguo de Heidelberg, Alemania",
    "Iglesia de San Nicolás, Praga, República Checa",
    "Castillo de Bran, Rumania",
    "Parque Güell, Barcelona, España",
    "Ópera de Oslo, Noruega",
    "La Costa Jurásica, Reino Unido",
    "Las Cuevas de Skocjan, Eslovenia",
    "Palacio Ducal, Venecia, Italia",
    "Plaza del Mercado, Cracovia, Polonia",
    "Fjord de Sogne, Noruega",
    "Parque Nacional de Dartmoor, Reino Unido",
    "Museo de Pérgamo, Berlín, Alemania",
    "Catedral de Durham, Reino Unido",
    "Puente Vasco da Gama, Lisboa, Portugal",
    "Museo Sorolla, Madrid, España",
    "La Avenida de los Campos Elíseos, París, Francia",
    "Abadía de Westminster, Londres, Reino Unido",
    "Museo Arqueológico Nacional, Atenas, Grecia",
    "La Ópera Garnier, París, Francia",
    "Bosque Negro, Alemania",
    "Monte Vesubio, Italia",
    "Los Dólmenes de Antequera, Málaga, España",
    "Palacio Real de Aranjuez, Madrid, España",
    "Castillo de Heidelberg, Alemania",
    "Playa de Navagio, Zakynthos, Grecia",
    "Museo Picasso, Barcelona, España",
    "Castillo de Chillon, Suiza",
    "La Torre de Clérigos, Oporto, Portugal",
    "Palacio de Knossos, Creta, Grecia",
    "Los acantilados de Étretat, Francia",
    "El Palacio de Potala, Lhasa, Tibet",
    "Sarek National Park, Suecia",
    "La Laguna Azul, Islandia",
    "La Isla de Gozo, Malta",
    "Monte Conero, Italia",
    "Karlovy Vary, República Checa",
    "Cabo da Roca, Portugal",
    "La Playa de la Concha, San Sebastián, España",
    "La Catedral de la Asunción, Cluj-Napoca, Rumania",
    "Las Islas Lofoten, Noruega",
    "Bastión de los Pescadores, Budapest, Hungría",
    "El Monasterio de Rila, Bulgaria"
]

# %%
print(len(emblematic_european_sites))
# Out:
# 175

# %%
# PASS the list to a .txt

with open('emblematic_european_sites.inp', 'w') as file:
    for site in emblematic_european_sites:
        file.write(site + '\n')

# %% [markdown]
# # DISTANCES FROM COORDENATES

# %%
import math

def haversine_distance(lat1, lon1, lat2, lon2):
    # Convert latitude and longitude from degrees to radians
    lat1, lon1, lat2, lon2 = map(math.radians, [lat1, lon1, lat2, lon2])

    # Haversine formula
    dlat = lat2 - lat1
    dlon = lon2 - lon1
    a = math.sin(dlat/2)**2 + math.cos(lat1) * math.cos(lat2) * math.sin(dlon/2)**2
    c = 2 * math.asin(math.sqrt(a))

    # Radius of Earth in kilometers. Use 3956 for miles
    r = 6371

    # Calculate the result
    return c * r

# Example usage
latitude1 = 52.2296756
longitude1 = 21.0122287
latitude2 = 41.8919300
longitude2 = 12.5113300

distance = haversine_distance(latitude1, longitude1, latitude2, longitude2)
print(f"The distance between the two points is {distance:.2f} kilometers.")
# Out:
# The distance between the two points is 1315.51 kilometers.

# %% [markdown]
# # BAIGES GET IMAGES

# %%
import requests
import os

def fetch_images(api_key, text_search, num_images=10):
    """
    Fetches images from Flickr API based on a text search, ensuring it gathers a specified number of valid image URLs.

    Args:
        api_key (str): Flickr API key
        text_search (str): Text to search for
        num_images (int): Desired number of images to fetch

    Returns:
        list: List of image URLs
    """
    url = 'https://api.flickr.com/services/rest/'
    images = []
    page = 1

    while len(images) < num_images:
        params = {
            'method': 'flickr.photos.search',
            'api_key': api_key,
            'text': text_search,
            'sort': 'relevance',
            'media': 'photos',
            'safe_search': 1,
            'extras': 'url_l',  # 'url_l' is more likely to be available
            'format': 'json',
            'nojsoncallback': 1,
            'per_page': 100,  # Fetch more photos per request
            'page': page
        }

        try:
            response = requests.get(url, params=params)
            response.raise_for_status()
            photos = response.json()['photos']['photo']
            for photo in photos:
                if 'url_l' in photo and len(images) < num_images:
                    images.append(photo['url_l'])
            page += 1
        except requests.RequestException as e:
            print(f"Error fetching data: {e}")
            break

    return images

def save_images(images, directory, text_search):
    """
    Saves a list of images to a directory with filenames based on the search term.

    Args:
        images (list): List of image URLs
        directory (str): Directory to save the images
        text_search (str): Text search term used to name the files

    Returns:
        None
    """
    if not os.path.exists(directory):
        os.makedirs(directory)
    for i, image_url in enumerate(images):
        filename = f'{text_search.replace(" ", "_")}_{i+1}.jpg'  # Replace spaces with underscores and append the index
        try:
            response = requests.get(image_url)
            response.raise_for_status()
            with open(os.path.join(directory, filename), 'wb') as f:
                f.write(response.content)
            print(f'Image {filename} saved successfully.')
        except requests.RequestException as e:
            print(f"Error downloading image {filename}: {e}")

# %%
import pandas as pd

dataset_landmarks = pd.read_csv('data.csv')

# Find the Landmark column

landmarks = dataset_landmarks['landmark']

# Fetch images for each landmark

api_key = '92ff34d601ef59b346f4a09a9e2b0e6c'

for i, landmark in enumerate(landmarks):
    print(f"Fetching images for landmark {i+1}/{len(landmarks)}: {landmark}")
    images = fetch_images(api_key, landmark, num_images=3)
    save_images(images, 'downloaded_images', landmark)
# Out:
# Fetching images for landmark 1/141: Eiffel Tower, Paris, France
# Image Eiffel_Tower,_Paris,_France_1.jpg saved successfully.
# Image Eiffel_Tower,_Paris,_France_2.jpg saved successfully.
# Image Eiffel_Tower,_Paris,_France_3.jpg saved successfully.
# Fetching images for landmark 2/141: Colosseum, Rome, Italy
# Image Colosseum,_Rome,_Italy_1.jpg saved successfully.
# Image Colosseum,_Rome,_Italy_2.jpg saved successfully.
# Image Colosseum,_Rome,_Italy_3.jpg saved successfully.
# Fetching images for landmark 3/141: Sagrada Familia, Barcelona, Spain
# Image Sagrada_Familia,_Barcelona,_Spain_1.jpg saved successfully.
# Image Sagrada_Familia,_Barcelona,_Spain_2.jpg saved successfully.
# Image Sagrada_Familia,_Barcelona,_Spain_3.jpg saved successfully.
# Fetching images for landmark 4/141: Acropolis of Athens, Greece
# Image Acropolis_of_Athens,_Greece_1.jpg saved successfully.
# Image Acropolis_of_Athens,_Greece_2.jpg saved successfully.
# ...

# %%
# Calculate how many images were downloaded

downloaded_images = os.listdir('downloaded_images')
print(f"Downloaded {len(downloaded_images)} images.")
# Out:
# Downloaded 399 images.

# %% [markdown]
# # IMAGES EMBEDDINGS

# %%
import torch
from torchvision import models, transforms
from torch.nn.functional import cosine_similarity
from PIL import Image
import glob
import re
import os


def load_image(image_path):
    """
    Load an image from a file and apply the necessary transformations

    Args:
        image_path (str): Path to the image file

    Returns:
        torch.Tensor: Transformed image tensor
    """
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    image = Image.open(image_path).convert('RGB')  # Convertir la imagen a RGB
    image = transform(image).unsqueeze(0)  # Añade una dimensión al principio
    return image


def get_embedding(model, image_tensor):
    """
    Get the embedding of an image from a pre-trained model

    Args:
        model (torch.nn.Module): Pre-trained model
        image_tensor (torch.Tensor): Image tensor

    Returns:
        torch.Tensor: Image embedding
    """
    with torch.no_grad():
        embedding = model(image_tensor)
    
    return embedding

def find_most_similar(reference_embedding, embeddings):
    """
    Find the index of the most similar image to a reference embedding

    Args:
        reference_embedding (torch.Tensor): Reference embedding
        embeddings (list): List of embeddings

    Returns:
        int: Index of the most similar image
    """
    similarities = [cosine_similarity(reference_embedding, emb, dim=1) for emb in embeddings]

    # Find the top 3 most similar images
    most_similar_indices = sorted(range(len(similarities)), key=lambda i: similarities[i], reverse=True)[:3]
    return most_similar_indices

# Load a pre-trained ResNet model
model = models.resnet18(pretrained=True)
model.eval()

# Extract the embeddings of the images
reference_image_path = "fib.jpg"
image_list_paths = glob.glob("downloaded_images/*.jpg")

reference_image = load_image(reference_image_path)
reference_embedding = get_embedding(model, reference_image)

image_embeddings = [get_embedding(model, load_image(img_path)) for img_path in image_list_paths]

# Find the most similar image to the reference image
most_similar_index = find_most_similar(reference_embedding, image_embeddings)

# Find the most similar real landmarks

def clean_image_name(file_path):
    # Delete the directory path and the file extension
    base_name = os.path.basename(file_path).replace('.jpg', '')
    
    # Delete any numbers and underscores at the end of the file name
    clean_name = re.sub(r'_[0-9]+$', '', base_name)
    
    # Replace any remaining underscores with spaces
    clean_name = clean_name.replace('_', ' ')
    
    return clean_name

filenames = [clean_image_name(image_list_paths[i]) for i in most_similar_index]

print("The most similar images are:", filenames)

print("The most similar image is at index:", most_similar_index[0], "Path:", image_list_paths[most_similar_index[0]])
print("The second most similar image is at index:", most_similar_index[1], "Path:", image_list_paths[most_similar_index[1]])
print("The third most similar image is at index:", most_similar_index[2], "Path:", image_list_paths[most_similar_index[2]])


# Visualize the top 3 most similar images

import matplotlib.pyplot as plt

fig, axs = plt.subplots(1, 4, figsize=(15, 5))

# Load and plot the reference image
reference_image = Image.open(reference_image_path)
axs[0].imshow(reference_image)
axs[0].set_title("Reference Image")
axs[0].axis('off')

# Load and plot the most similar image
most_similar_image = Image.open(image_list_paths[most_similar_index[0]])
axs[1].imshow(most_similar_image)
axs[1].set_title(f'Most Similar Image: {most_similar_index[0]}')
axs[1].axis('off')

# Load and plot the second most similar image
second_most_similar_image = Image.open(image_list_paths[most_similar_index[1]])
axs[2].imshow(second_most_similar_image)
axs[2].set_title(f'Secong Most Similar Image: {most_similar_index[1]}')
axs[2].axis('off')

# Load and plot the third most similar image
third_most_similar_image = Image.open(image_list_paths[most_similar_index[2]])
axs[3].imshow(third_most_similar_image)
axs[3].set_title(f'Third Most Similar Image: {most_similar_index[2]}')
axs[3].axis('off')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# The most similar images are: ['Anne Frank House, Amsterdam, Netherlands', "St. Peter's Square, Vatican City", 'Alhambra, Granada, Spain']
# The most similar image is at index: 104 Path: downloaded_images/Anne_Frank_House,_Amsterdam,_Netherlands_2.jpg
# ...
